# %%
from empyrial import empyrial, Engine

# %%
portfolio = Engine(    
                  start_date= "2023-05-23", #start date for the backtesting
                  portfolio= ["AAPL","MSFT","AMZN","META"], #assets in your portfolio 
                  #weights = [0.2, 0.2, 0.2, 0.2], #equal weighting is set by default
                  benchmark = ["^NSEI"] #NIFTY50 is set by default
)

# %%
empyrial(portfolio)
# Out:
# Start date: 2023-05-23
# End date: 2023-10-20
#                     Backtest
#
# Annual return         30.64%
# Cumulative return     11.54%
# Annual volatility    20.59 %
# Winning day ratio     55.34%
# Sharpe ratio             1.4
# Calmar ratio            2.24
# Information ratio        0.0
# Stability               0.12
# Max Drawdown         -9.11 %
# Sortino ratio           2.05
# Skew                   -0.24
# Kurtosis               -0.27
# Tail Ratio              0.89
# Common sense ratio      1.11
# Daily value at risk   -2.0 %
# Alpha                   0.26
# Beta                     0.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 empyrial(portfolio)
#
# File ~/mambaforge/envs/perso/lib/python3.11/site-packages/empyrial/main.py:512, in empyrial(my_portfolio, rf, sigma_value, confidence_value, report, filename)
# ...
